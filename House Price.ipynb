# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
Raw_Data = pd.read_csv("kc_house_data.csv")
Raw_Data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
Raw_Data.shape
# Out:
# (21613, 21)

# %%
Raw_Data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
Raw_Data.describe(include="all")
# Out:
#                   id             date         price      bedrooms  \
# count   2.161300e+04            21613  2.161300e+04  21613.000000
# unique           NaN              372           NaN           NaN
# top              NaN  20140623T000000           NaN           NaN
# freq             NaN              142           NaN           NaN
# mean    4.580302e+09              NaN  5.400881e+05      3.370842
# std     2.876566e+09              NaN  3.671272e+05      0.930062
# min     1.000102e+06              NaN  7.500000e+04      0.000000
# 25%     2.123049e+09              NaN  3.219500e+05      3.000000
# 50%     3.904930e+09              NaN  4.500000e+05      3.000000
# 75%     7.308900e+09              NaN  6.450000e+05      4.000000
# max     9.900000e+09              NaN  7.700000e+06     33.000000
#
#            bathrooms   sqft_living      sqft_lot        floors    waterfront  \
# count   21613.000000  21613.000000  2.161300e+04  21613.000000  21613.000000
# ...

# %%
D1 = Raw_Data.drop("id",axis=1)
D1.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0         3       1.00         1180      5650
# 1  20141209T000000  538000.0         3       2.25         2570      7242
# 2  20150225T000000  180000.0         2       1.00          770     10000
# 3  20141209T000000  604000.0         4       3.00         1960      5000
# 4  20150218T000000  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
D1.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
sns.distplot(D1["price"])

# %%
quant = D1["price"].quantile(0.99)
D2 = D1[D1["price"] < quant]
print(quant)
# Out:
# 1964400.0000000051

# %%
sns.distplot(D2["price"])

# %%
D2.reset_index(drop=True)
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0       221900.0         3       1.00         1180      5650     1.0
# 1       538000.0         3       2.25         2570      7242     2.0
# 2       180000.0         2       1.00          770     10000     1.0
# 3       604000.0         4       3.00         1960      5000     1.0
# 4       510000.0         3       2.00         1680      8080     1.0
# 5      1225000.0         4       4.50         5420    101930     1.0
# 6       257500.0         3       2.25         1715      6819     2.0
# 7       291850.0         3       1.50         1060      9711     1.0
# 8       229500.0         3       1.00         1780      7470     1.0
# 9       323000.0         3       2.50         1890      6560     2.0
# 10      662500.0         3       2.50         3560      9796     1.0
# 11      468000.0         2       1.00         1160      6000     1.0
# 12      310000.0         3       1.00         1430     19901     1.5
# ...

# %%
D2.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
log_price = np.log(D2["price"])
D2["Log_Price"] = log_price
D2.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# ...

# %%
D3 = D2.drop("price",axis=1)
D3.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  Log_Price
# ...

# %%
D3.columns.values
# Out:
# array(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat',
#        'long', 'sqft_living15', 'sqft_lot15', 'Log_Price'], dtype=object)

# %%
cols = ['Log_Price','bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
       'waterfront', 'view', 'condition', 'grade', 'sqft_above',
       'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat',
       'long', 'sqft_living15', 'sqft_lot15']

# %%
Final_data = D3[cols]

# %%
Final_data.head()
# Out:
#    Log_Price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  12.309982         3       1.00         1180      5650     1.0           0
# 1  13.195614         3       2.25         2570      7242     2.0           0
# 2  12.100712         2       1.00          770     10000     1.0           0
# 3  13.311329         4       3.00         1960      5000     1.0           0
# 4  13.142166         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
x = Final_data.iloc[:, 1:19]
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
y = Final_data["Log_Price"]
y.head()
# Out:
# 0    12.309982
# 1    13.195614
# 2    12.100712
# 3    13.311329
# 4    13.142166
# Name: Log_Price, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler as SS

# %%
Scaler = SS()
Scaler.fit(x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_scaled = Scaler.transform(x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled,y,test_size=0.2,random_state=19)

# %%
from sklearn.linear_model import LinearRegression as LR

# %%
Reg = LR()
Reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
Reg.score(x_train,y_train)
# Out:
# 0.7491566395974361

# %%
Reg.score(x_test,y_test)
# Out:
# 0.7524581275846461

# %%
y_hat = Reg.predict(x_train)

# %%
plt.scatter(y_train,y_hat)
plt.xlabel("Actual",fontsize=20)
plt.ylabel("Predicted",fontsize=20)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.scatter(y_train,y_hat,alpha=0.3)
plt.xlabel("Actual",fontsize=20)
plt.ylabel("Predicted",fontsize=20)
plt.show()

# %%
sns.distplot(y_train - y_hat)

# %%
Reg.score(x_train,y_train)
# Out:
# 0.7491566395974361

# %%
Reg.score(x_test,y_test)
# Out:
# 0.7524581275846461

# %%
Reg.intercept_
# Out:
# 13.030435003814041

# %%
Reg.coef_
# Out:
# array([-7.29014141e-03,  4.62823260e-02, -1.99939025e+12,  1.76869831e-02,
#         4.53363089e-02,  2.57622558e-02,  4.17523028e-02,  3.94722845e-02,
#         1.78850194e-01,  1.83734622e+12,  9.98993166e+11, -9.93990563e-02,
#         1.34055933e-02, -3.02820400e-02,  1.93360351e-01, -1.53862171e-02,
#         6.29560031e-02, -3.33027760e-03])

# %%
reg_summary = pd.DataFrame(x.columns.values, columns=["Features"])
reg_summary["Weights"] = Reg.coef_
reg_summary
# Out:
#          Features       Weights
# 0        bedrooms -7.290141e-03
# 1       bathrooms  4.628233e-02
# 2     sqft_living -1.999390e+12
# 3        sqft_lot  1.768698e-02
# 4          floors  4.533631e-02
# 5      waterfront  2.576226e-02
# 6            view  4.175230e-02
# 7       condition  3.947228e-02
# 8           grade  1.788502e-01
# 9      sqft_above  1.837346e+12
# 10  sqft_basement  9.989932e+11
# 11       yr_built -9.939906e-02
# 12   yr_renovated  1.340559e-02
# 13        zipcode -3.028204e-02
# 14            lat  1.933604e-01
# 15           long -1.538622e-02
# 16  sqft_living15  6.295600e-02
# 17     sqft_lot15 -3.330278e-03

# %%
x_imp = x.iloc[:, 1:19]
x_imp.head()
# Out:
#    bathrooms  sqft_living  sqft_lot  floors  waterfront  view  condition  \
# 0       1.00         1180      5650     1.0           0     0          3
# 1       2.25         2570      7242     2.0           0     0          3
# 2       1.00          770     10000     1.0           0     0          3
# 3       3.00         1960      5000     1.0           0     0          5
# 4       2.00         1680      8080     1.0           0     0          3
#
#    grade  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0      7        1180              0      1955             0    98178  47.5112
# 1      7        2170            400      1951          1991    98125  47.7210
# 2      6         770              0      1933             0    98028  47.7379
# 3      7        1050            910      1965             0    98136  47.5208
# 4      8        1680              0      1987             0    98074  47.6168
#
#       long  sqft_living15  sqft_lot15
# ...

# %%
x_imp.head()
# Out:
#    bathrooms  sqft_living  sqft_lot  floors  waterfront  view  condition  \
# 0       1.00         1180      5650     1.0           0     0          3
# 1       2.25         2570      7242     2.0           0     0          3
# 2       1.00          770     10000     1.0           0     0          3
# 3       3.00         1960      5000     1.0           0     0          5
# 4       2.00         1680      8080     1.0           0     0          3
#
#    grade  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode  \
# 0      7        1180              0      1955             0    98178
# 1      7        2170            400      1951          1991    98125
# 2      6         770              0      1933             0    98028
# 3      7        1050            910      1965             0    98136
# 4      8        1680              0      1987             0    98074
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# ...

# %%
Scaler.fit(x_imp)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_imp_scaled = Scaler.transform(x_imp)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   """Entry point for launching an IPython kernel.

# %%
x_imp_train, x_imp_test, y_train, y_test = train_test_split(x_imp_scaled,y,test_size=0.2,random_state=121)

# %%
x_imp_train.shape
# Out:
# (17116, 15)

# %%
y_train.shape
# Out:
# (17116,)

# %%
Reg2 = LR()
Reg2.fit(x_imp_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
Reg2.score(x_imp_train,y_train)
# Out:
# 0.620354205343159

# %%
Reg2.score(x_imp_test,y_test)
# Out:
# 0.6267496541000739

# %%
Pred = pd.DataFrame(np.exp(y_hat), columns=["Price"])
Pred.head()
# Out:
#           Price
# 0  6.089537e+05
# 1  1.107529e+06
# 2  6.037724e+05
# 3  7.506276e+05
# 4  2.532925e+05

# %%
Pred["Actual"] = y_train
Pred.head()
# Out:
#           Price     Actual
# 0  6.089537e+05  12.309982
# 1  1.107529e+06        NaN
# 2  6.037724e+05        NaN
# 3  7.506276e+05  13.311329
# 4  2.532925e+05        NaN

# %%
y_train
y_train.reset_index(drop=True,inplace=True)

# %%
Pred["Actual"] = np.exp(y_test)
Pred.head()
# Out:
#           Price    Actual
# 0  6.089537e+05       NaN
# 1  1.107529e+06  538000.0
# 2  6.037724e+05  180000.0
# 3  7.506276e+05       NaN
# 4  2.532925e+05  510000.0
